# %%
# Imports and whatnot
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %%
inputshape = (6, 5, 150)
# timeframe, features, window

def Chirp_CNN():
    model = Sequential()

    model.add(keras.Input(shape=inputshape))
    # flatten data
    model.add(Flatten())
    # Dropout
    #model.add(Dropout(0.2))

    model.add(Dense(6000, activation='silu'))
    model.add(Dropout(0.01))
    model.add(Dense(4000, activation='silu'))
    model.add(Dropout(0.01))
    model.add(Dense(3000, activation='silu'))
    model.add(Dropout(0.01))

    # Lets converge
    model.add(Dense(1000, activation='silu'))
    model.add(Dense(500, activation='silu'))
    # apply dropout with rate 0.1
    model.add(Dropout(0.1))
    # More density, lets try a sigmoid
    model.add(Dense(50, activation='silu'))
    model.add(Dense(20, activation='silu'))

    # output
    model.add(Dense(2))

    return model

def compile_model(optimizer=keras.optimizers.Adam(amsgrad=True)):
    # create the model
    model=Chirp_CNN()
    # compile the model
    model.compile(loss=keras.losses.mean_squared_error,
                  optimizer=keras.optimizers.Adam(amsgrad=True),
                  # For the metrics, always have AT LEAST these two
                  metrics=["MeanAbsolutePercentageError", "MeanSquaredError"])
    return model

# %%
Model_Name = "dingus2"

model = compile_model()
print("Model Compiled")
model.summary()
# Out:
# Model Compiled
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)             │ (None, 4500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 6000)           │    27,006,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 6000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 4000)           │    24,004,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 4000)           │             0 │
# ...

# %%
model.save("models/"+Model_Name+"/model.keras", overwrite = True)
print("Model Saved to "+ "models/"+Model_Name+"/model.keras")
# Out:
# Model Saved to models/dingus2/model.keras
