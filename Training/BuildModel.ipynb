# %%
# Imports and whatnot
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %%
inputshape = (6, 5, 50)
# timeframe, features, window

def compile_model(model):
    # create the model
    # compile the model
    model.compile(loss=keras.losses.mean_squared_error,
                  optimizer=keras.optimizers.Adam(amsgrad=True),
                  # For the metrics, always have AT LEAST these two
                  metrics=["MeanAbsolutePercentageError", "MeanSquaredError"])
    return model

# %%
def dingus3():
    inputs = keras.Input(shape=inputshape)
    x = Flatten()(inputs)

    x = Dense(6000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(6000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1000, activation='silu')(x)
    x = Dense(5000, activation='silu')(x)

    outputminmax = Dense(2, name = "minmaxprediction")(x)
    outputerrors = Dense(2, activation='relu', name = "errorprediction")(x)

    outputs = keras.layers.concatenate([outputminmax, outputerrors])

    return keras.Model(inputs=inputs, outputs=outputs)

# %%
def dingus4():
    inputs = keras.Input(shape=inputshape)
    x = Flatten()(inputs)

    x = Dense(6000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(6000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(5000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1000, activation='silu')(x)

    minmax = Dense(2, name = "minmax")(x)
    errors = Dense(2, activation='relu', name = "error")(x)
    decision = Dense(3, activation="softmax", name="decision")(x)

    outputs = keras.layers.concatenate([minmax, errors, decision])

    return keras.Model(inputs=inputs, outputs=outputs)

# %%
def dingus6():
    inputs = keras.Input(shape=inputshape)
    x = Flatten()(inputs)

    x = Dense(6000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(6000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(5000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(5000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1000, activation='silu')(x)

    minmax = Dense(2, name = "minmax")(x)
    errors = Dense(2, activation='relu', name = "error")(x)
    decision = Dense(3, activation="softmax", name="decision")(x)

    outputs = keras.layers.concatenate([minmax, errors, decision])

    return keras.Model(inputs=inputs, outputs=outputs)

# %%
def dingus7():
    inputs = keras.Input(shape=inputshape)
    x = Flatten()(inputs)

    x = Dense(2000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(2000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1500, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1000, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(700, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(500, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(500, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(500, activation='silu')(x)
    x = Dropout(0.1)(x)
    x = Dense(250, activation='silu')(x)

    minmax = Dense(2, name = "minmax")(x)
    errors = Dense(2, activation='relu', name = "error")(x)
    decision = Dense(3, activation="softmax", name="decision")(x)

    outputs = keras.layers.concatenate([minmax, errors, decision])

    return keras.Model(inputs=inputs, outputs=outputs)

# %%
Model_Name = "dingus7"

model = compile_model(dingus7())
print("Model Compiled")
model.summary()
# Out:
# Model Compiled
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 6, 5, 50)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 1500)      │          0 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 2000)      │  3,002,000 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 2000)      │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ...

# %%
model.save("models/"+Model_Name+"/model.keras", overwrite = True)
print("Model Saved to "+ "models/"+Model_Name+"/model.keras")
# Out:
# Model Saved to models/dingus7/model.keras
