# %%
# Imports and whatnot
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
# Out:
# 2025-02-01 18:40:45.815925: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738431645.828901   20361 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738431645.832670   20361 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-01 18:40:45.850981: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
inputshape = (5, 5, 100)

def Chirp_CNN():
    model = Sequential()

    model.add(keras.Input(shape=inputshape))
    model.add(keras.layers.Normalization())
    # flatten data
    model.add(Flatten())
    # Dropout
    #model.add(Dropout(0.2))

    #model.add(Dense(1000, activation='tanh'))
    #model.add(Dense(1000, activation='tanh'))
    #model.add(Dense(1000, activation='tanh'))

    # add a dense all-to-all relu layer
    #model.add(Dense(500, activation='tanh'))
    #model.add(Dense(100, activation='tanh'))
    # apply dropout with rate 0.1
    #model.add(Dropout(0.1))
    # More density, lets try a sigmoid
    #model.add(Dense(50, activation='tanh'))
    model.add(Dense(20, activation='tanh'))

    # output
    model.add(Dense(2))

    return model

def compile_model(optimizer=keras.optimizers.Adam(clipnorm=1, learning_rate=0.1)):
    # create the model
    model=Chirp_CNN()
    # compile the model
    model.compile(loss=keras.losses.mean_squared_error,
                  optimizer=optimizer,
                  # For the metrics, always have AT LEAST these two
                  metrics=["MeanAbsolutePercentageError", "MeanSquaredError"])
    return model

# %%
Model_Name = "modeltest"

model = compile_model()
print("Model Compiled")
model.summary()
# Out:
# Model Compiled
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_3 (Normalization) │ (None, 5, 5, 100)      │           201 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_10 (Flatten)            │ (None, 2500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 20)             │        50,020 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 2)              │            42 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,263 (196.34 KB)
#  Trainable params: 50,062 (195.55 KB)
#  Non-trainable params: 201 (808.00 B)

# %%
model.save("models/"+Model_Name+"/model.keras", overwrite = True)
print("Model Saved to "+ "models/"+Model_Name+"/model.keras")
# Out:
# Model Saved to models/modeltest/model.keras
